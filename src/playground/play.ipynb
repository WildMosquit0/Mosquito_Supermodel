# %%
import os
import cv2
import pandas as pd
import torch
import json
from ultralytics import YOLO
from datetime import datetime


class Tracker:
    def __init__(self, config_path: str):
        """
        Initialize the Tracker with a configuration file.
        Args:
            config_path (str): Path to the JSON configuration file.
        """
        # Load configuration
        with open(config_path, "r") as config_file:
            self.config = json.load(config_file)

        # Extract settings from the configuration
        self.model_path = self.config["model"]["weights"]
        self.conf_threshold = self.config["model"]["conf_threshold"]
        self.iou_threshold = self.config["model"]["iou_threshold"]

        self.input_dir = self.config["input"]["images_dir"]
        self.output_dir = self.config["output"]["output_dir"]
        self.save_video = self.config["output"]["save_video"]


        # Ensure output directory exists
        os.makedirs(self.output_dir, exist_ok=True)

        # Initialize YOLO model
        if not os.path.exists(self.model_path):
            raise FileNotFoundError(f"Model file {self.model_path} does not exist.")
        self.model = YOLO(self.model_path)
        self.model.to("cuda" if torch.cuda.is_available() else "cpu")

        # Prepare for tracking
        self.global_track_id = 0
        self.track_memory = {}  # Tracks global IDs for cross-image tracking
        self.tracking_data = []  # Store results for all files

    def _process_video(self, video_path: str):
        """
        Process a video file for object tracking.
        Args:
            video_path (str): Path to the video file.
        """
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            print(f"Error: Unable to open video file {video_path}")
            return

        video_name = os.path.basename(video_path)
        video_output_dir = os.path.join(self.output_dir, "annotated_videos")
        os.makedirs(video_output_dir, exist_ok=True)
        output_video_path = os.path.join(video_output_dir, f"annotated_{video_name}")

        try:
            while cap.isOpened():
                success, frame = cap.read()
                if not success:
                    break

                # Get current frame number
                frame_number = int(cap.get(cv2.CAP_PROP_POS_FRAMES))

                # Run YOLO tracking
                try:
                    results = self.model.track(
                        frame,
                        conf=self.conf_threshold,
                        iou=self.iou_threshold,
                        persist=True,
                        save=self.save_video,
                    )

                    # Save annotated frame to video if `save_video` is True
                    if self.save_video:
                        annotated_frame = results[0].plot()
                        if "video_writer" not in locals():
                            # Initialize video writer if not already done
                            fourcc = cv2.VideoWriter_fourcc(*"mp4v")
                            frame_height, frame_width = annotated_frame.shape[:2]
                            video_writer = cv2.VideoWriter(
                                output_video_path, fourcc, cap.get(cv2.CAP_PROP_FPS), (frame_width, frame_height)
                            )
                        video_writer.write(annotated_frame)

                    # Check if there are detections
                    if results and results[0].boxes is not None:
                        boxes = results[0].boxes.xywh.cpu().numpy()  # Bounding boxes
                        track_ids = results[0].boxes.id.cpu().numpy().tolist()  # Track IDs

                        # Append tracking data
                        for box, track_id in zip(boxes, track_ids):
                            x, y, w, h = box
                            self.tracking_data.append([track_id, x, y, w, h, os.path.basename(video_path), frame_number])
                    else:
                        print(f"No detections in frame {frame_number}.")

                except Exception as e:
                    print(f"Error processing frame {frame_number}: {e}")

        except Exception as e:
            print(f"Error processing video {video_path}: {e}")
        finally:
            cap.release()
            # Release video writer
            if "video_writer" in locals():
                video_writer.release()

    def _process_image(self, image_path: str):
        """
        Process a single image for object tracking.
        Args:
            image_path (str): Path to the image file.
        """
        frame = cv2.imread(image_path)
        if frame is None:
            print(f"Error: Unable to open image file {image_path}")
            return

        results = self.model.track(frame, conf=self.conf_threshold, iou=self.iou_threshold, persist=True)

        if results and results[0].boxes is not None:
            boxes = results[0].boxes.xywh.cpu().numpy()
            track_ids = results[0].boxes.id.cpu().numpy().tolist()

            for box, track_id in zip(boxes, track_ids):
                if track_id not in self.track_memory:
                    self.global_track_id += 1
                    self.track_memory[track_id] = self.global_track_id

                global_id = self.track_memory[track_id]
                x, y, w, h = box
                self.tracking_data.append([global_id, x, y, w, h, os.path.basename(image_path), 0])

    def __call__(self):
        """
        Process all images and videos in the input directory or a single file.
        """
        if os.path.isfile(self.input_dir):
            # Process a single file
            input_files = [self.input_dir]
        elif os.path.isdir(self.input_dir):
            # Get all files from the input directory
            input_files = [
                os.path.join(self.input_dir, f)
                for f in os.listdir(self.input_dir)
                if f.lower().endswith((".mp4", ".avi", ".jpg", ".jpeg", ".png"))
            ]
        else:
            raise NotADirectoryError(f"The input path {self.input_dir} is neither a file nor a directory.")

        for input_file in sorted(input_files):
            if input_file.lower().endswith((".mp4", ".avi")):
                print(f"Processing video: {input_file}")
                self._process_video(input_file)
            elif input_file.lower().endswith((".jpg", ".jpeg", ".png")):
                print(f"Processing image: {input_file}")
                self._process_image(input_file)

        # Save results to a CSV file
        output_csv = os.path.join(self.output_dir, "tracking_results.csv")
        df = pd.DataFrame(self.tracking_data, columns=["track_id", "x", "y", "w", "h", "file_name", "frame_number"])
        df.to_csv(output_csv, index=False)
        print(f"Tracking results saved to {output_csv}")

# Usage
if __name__ == "__main__":
    tracker = Tracker(config_path="config.json")
    tracker()  # Call the instance to process files
# Out:
# Processing video: src/tests/13413819-hd_1920_1080_30fps.mp4
#
# 0: 384x640 (no detections), 139.8ms
# Speed: 16.9ms preprocess, 139.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 1: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 61.6ms
# Speed: 3.0ms preprocess, 61.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 2: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 65.6ms
# Speed: 2.0ms preprocess, 65.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 3: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 79.1ms
# Speed: 11.0ms preprocess, 79.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 4: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 152.4ms
# Speed: 2.1ms preprocess, 152.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 5: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 57.0ms
# Speed: 3.7ms preprocess, 57.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 6: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 7: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 58.0ms
# Speed: 0.0ms preprocess, 58.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 8: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 56.2ms
# Speed: 2.1ms preprocess, 56.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 9: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 54.1ms
# Speed: 15.6ms preprocess, 54.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 10: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 58.5ms
# Speed: 14.8ms preprocess, 58.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 11: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 60.6ms
# Speed: 0.0ms preprocess, 60.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 12: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 45.6ms
# Speed: 11.0ms preprocess, 45.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 13: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 49.2ms
# Speed: 2.0ms preprocess, 49.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 14: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 68.3ms
# Speed: 0.0ms preprocess, 68.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 15: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 57.3ms
# Speed: 7.3ms preprocess, 57.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 16: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 56.9ms
# Speed: 0.0ms preprocess, 56.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 17: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 64.2ms
# Speed: 0.0ms preprocess, 64.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 18: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 47.1ms
# Speed: 2.0ms preprocess, 47.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 19: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 1 person, 59.8ms
# Speed: 2.0ms preprocess, 59.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 61.8ms
# Speed: 6.2ms preprocess, 61.8ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 65.8ms
# Speed: 0.0ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 55.5ms
# Speed: 0.0ms preprocess, 55.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 72.5ms
# Speed: 0.0ms preprocess, 72.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 52.8ms
# Speed: 17.1ms preprocess, 52.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 78.4ms
# Speed: 0.0ms preprocess, 78.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 48.6ms
# Speed: 15.0ms preprocess, 48.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.7ms
# Speed: 0.0ms preprocess, 62.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 68.9ms
# Speed: 0.0ms preprocess, 68.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 51.5ms
# Speed: 3.6ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 66.5ms
# Speed: 0.0ms preprocess, 66.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 68.5ms
# Speed: 0.0ms preprocess, 68.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 52.2ms
# Speed: 11.2ms preprocess, 52.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 55.3ms
# Speed: 13.9ms preprocess, 55.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 65.0ms
# Speed: 0.0ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 67.2ms
# Speed: 2.9ms preprocess, 67.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 71.8ms
# Speed: 4.1ms preprocess, 71.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 61.6ms
# Speed: 0.0ms preprocess, 61.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.1ms
# Speed: 0.0ms preprocess, 62.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 148.3ms
# Speed: 2.6ms preprocess, 148.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 52.9ms
# Speed: 3.7ms preprocess, 52.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 68.8ms
# Speed: 0.0ms preprocess, 68.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 55.3ms
# Speed: 0.0ms preprocess, 55.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 69.1ms
# Speed: 15.6ms preprocess, 69.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 63.6ms
# Speed: 4.4ms preprocess, 63.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 57.2ms
# Speed: 2.0ms preprocess, 57.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 48.8ms
# Speed: 2.5ms preprocess, 48.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 56.3ms
# Speed: 0.0ms preprocess, 56.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 52.5ms
# Speed: 0.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 50.5ms
# Speed: 15.5ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 47.3ms
# Speed: 15.6ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 57.5ms
# Speed: 0.0ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 48.7ms
# Speed: 15.7ms preprocess, 48.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 49.1ms
# Speed: 3.0ms preprocess, 49.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 48.3ms
# Speed: 2.0ms preprocess, 48.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 60.1ms
# Speed: 0.0ms preprocess, 60.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 51.3ms
# Speed: 1.0ms preprocess, 51.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.6ms
# Speed: 0.0ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 54.6ms
# Speed: 0.0ms preprocess, 54.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 52.1ms
# Speed: 0.0ms preprocess, 52.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 53.4ms
# Speed: 15.8ms preprocess, 53.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 54.8ms
# Speed: 0.0ms preprocess, 54.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 63.7ms
# Speed: 0.0ms preprocess, 63.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 60.9ms
# Speed: 0.0ms preprocess, 60.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 63.3ms
# Speed: 0.0ms preprocess, 63.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 58.9ms
# Speed: 0.0ms preprocess, 58.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 59.6ms
# Speed: 0.0ms preprocess, 59.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 65.7ms
# Speed: 0.0ms preprocess, 65.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 57.3ms
# Speed: 0.0ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 50.7ms
# Speed: 3.0ms preprocess, 50.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 54.9ms
# Speed: 0.0ms preprocess, 54.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 59.3ms
# Speed: 0.0ms preprocess, 59.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 55.6ms
# Speed: 2.0ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 94.2ms
# Speed: 0.0ms preprocess, 94.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 54.1ms
# Speed: 8.8ms preprocess, 54.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 61.2ms
# Speed: 0.0ms preprocess, 61.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.1ms
# Speed: 0.0ms preprocess, 62.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 64.9ms
# Speed: 3.0ms preprocess, 64.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 53.0ms
# Speed: 3.5ms preprocess, 53.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 51.6ms
# Speed: 2.5ms preprocess, 51.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 58.6ms
# Speed: 3.4ms preprocess, 58.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 61.4ms
# Speed: 2.0ms preprocess, 61.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 47.0ms
# Speed: 2.0ms preprocess, 47.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 56.3ms
# Speed: 6.5ms preprocess, 56.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 49.4ms
# Speed: 2.5ms preprocess, 49.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 53.3ms
# Speed: 3.0ms preprocess, 53.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 47.2ms
# Speed: 1.9ms preprocess, 47.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.2ms
# Speed: 2.5ms preprocess, 62.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 54.1ms
# Speed: 2.9ms preprocess, 54.1ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 60.9ms
# Speed: 0.0ms preprocess, 60.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 60.6ms
# Speed: 0.0ms preprocess, 60.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 57.3ms
# Speed: 3.0ms preprocess, 57.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 57.9ms
# Speed: 2.9ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 71.0ms
# Speed: 8.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 52.1ms
# Speed: 0.0ms preprocess, 52.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 49.7ms
# Speed: 3.0ms preprocess, 49.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 65.4ms
# Speed: 0.0ms preprocess, 65.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.2ms
# Speed: 0.0ms preprocess, 62.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 57.2ms
# Speed: 0.0ms preprocess, 57.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 63.3ms
# Speed: 0.0ms preprocess, 63.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 50.8ms
# Speed: 0.0ms preprocess, 50.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 53.1ms
# Speed: 1.4ms preprocess, 53.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 72.7ms
# Speed: 0.0ms preprocess, 72.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 52.1ms
# Speed: 8.5ms preprocess, 52.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 66.3ms
# Speed: 0.0ms preprocess, 66.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 77.0ms
# Speed: 8.8ms preprocess, 77.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 50.9ms
# Speed: 2.0ms preprocess, 50.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 59.6ms
# Speed: 0.0ms preprocess, 59.6ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 61.6ms
# Speed: 0.0ms preprocess, 61.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 56.5ms
# Speed: 0.0ms preprocess, 56.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 58.2ms
# Speed: 0.0ms preprocess, 58.2ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 67.1ms
# Speed: 3.0ms preprocess, 67.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 46.4ms
# Speed: 3.0ms preprocess, 46.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 59.3ms
# Speed: 8.7ms preprocess, 59.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 70.2ms
# Speed: 3.0ms preprocess, 70.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 56.0ms
# Speed: 2.5ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 63.3ms
# Speed: 3.1ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 65.3ms
# Speed: 0.0ms preprocess, 65.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 57.0ms
# Speed: 16.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 64.0ms
# Speed: 3.2ms preprocess, 64.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 64.8ms
# Speed: 0.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 52.5ms
# Speed: 2.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 63.3ms
# Speed: 2.0ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 55.0ms
# Speed: 3.7ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 49.5ms
# Speed: 10.5ms preprocess, 49.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 61.5ms
# Speed: 0.6ms preprocess, 61.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 64.9ms
# Speed: 0.0ms preprocess, 64.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 109.5ms
# Speed: 0.0ms preprocess, 109.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 54.3ms
# Speed: 3.0ms preprocess, 54.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 58.0ms
# Speed: 0.0ms preprocess, 58.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 55.3ms
# Speed: 3.0ms preprocess, 55.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 64.6ms
# Speed: 0.0ms preprocess, 64.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 60.9ms
# Speed: 3.0ms preprocess, 60.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 102.3ms
# Speed: 6.2ms preprocess, 102.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 58.1ms
# Speed: 0.0ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 58.1ms
# Speed: 14.3ms preprocess, 58.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 71.5ms
# Speed: 0.0ms preprocess, 71.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 56.5ms
# Speed: 9.2ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 51.5ms
# Speed: 2.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 55.2ms
# Speed: 5.5ms preprocess, 55.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 102.8ms
# Speed: 1.0ms preprocess, 102.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 56.6ms
# Speed: 0.0ms preprocess, 56.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 56.3ms
# Speed: 3.0ms preprocess, 56.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 49.2ms
# Speed: 2.0ms preprocess, 49.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.9ms
# Speed: 2.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 55.1ms
# Speed: 17.7ms preprocess, 55.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 85.8ms
# Speed: 0.0ms preprocess, 85.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 49.5ms
# Speed: 2.0ms preprocess, 49.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 61.8ms
# Speed: 15.6ms preprocess, 61.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 51.8ms
# Speed: 2.0ms preprocess, 51.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 59.1ms
# Speed: 2.0ms preprocess, 59.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 60.3ms
# Speed: 1.1ms preprocess, 60.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 107.2ms
# Speed: 0.0ms preprocess, 107.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 59.1ms
# Speed: 3.0ms preprocess, 59.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 63.2ms
# Speed: 2.0ms preprocess, 63.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 64.5ms
# Speed: 15.6ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 60.0ms
# Speed: 0.0ms preprocess, 60.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 56.6ms
# Speed: 3.0ms preprocess, 56.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 58.2ms
# Speed: 0.0ms preprocess, 58.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 157.6ms
# Speed: 0.0ms preprocess, 157.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 59.2ms
# Speed: 2.0ms preprocess, 59.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 68.8ms
# Speed: 0.0ms preprocess, 68.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 60.0ms
# Speed: 16.7ms preprocess, 60.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 59.2ms
# Speed: 0.0ms preprocess, 59.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 52.8ms
# Speed: 1.3ms preprocess, 52.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 53.3ms
# Speed: 0.0ms preprocess, 53.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 56.3ms
# Speed: 0.0ms preprocess, 56.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 68.3ms
# Speed: 0.0ms preprocess, 68.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 58.1ms
# Speed: 12.2ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 54.6ms
# Speed: 0.0ms preprocess, 54.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 46.3ms
# Speed: 15.6ms preprocess, 46.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 76.8ms
# Speed: 0.0ms preprocess, 76.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 60.6ms
# Speed: 3.3ms preprocess, 60.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 57.8ms
# Speed: 15.0ms preprocess, 57.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 64.8ms
# Speed: 0.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 60.5ms
# Speed: 11.9ms preprocess, 60.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 41.0ms
# Speed: 0.0ms preprocess, 41.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 64.2ms
# Speed: 0.0ms preprocess, 64.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 53.3ms
# Speed: 12.5ms preprocess, 53.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 52.8ms
# Speed: 0.0ms preprocess, 52.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 64.9ms
# Speed: 0.0ms preprocess, 64.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 56.5ms
# Speed: 0.0ms preprocess, 56.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 65.9ms
# Speed: 0.0ms preprocess, 65.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 48.6ms
# Speed: 9.0ms preprocess, 48.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 57.6ms
# Speed: 6.5ms preprocess, 57.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.1ms
# Speed: 0.0ms preprocess, 62.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 60.3ms
# Speed: 0.0ms preprocess, 60.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 58.2ms
# Speed: 0.0ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.7ms
# Speed: 0.0ms preprocess, 62.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 54.3ms
# Speed: 2.8ms preprocess, 54.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 60.4ms
# Speed: 0.0ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 58.4ms
# Speed: 0.0ms preprocess, 58.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 65.2ms
# Speed: 0.0ms preprocess, 65.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 53.5ms
# Speed: 0.0ms preprocess, 53.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 53.9ms
# Speed: 3.0ms preprocess, 53.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.7ms
# Speed: 0.0ms preprocess, 62.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 54.0ms
# Speed: 0.6ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 60.4ms
# Speed: 0.0ms preprocess, 60.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 55.3ms
# Speed: 0.0ms preprocess, 55.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 66.4ms
# Speed: 0.0ms preprocess, 66.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 88.5ms
# Speed: 2.0ms preprocess, 88.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 54.8ms
# Speed: 0.0ms preprocess, 54.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 72.0ms
# Speed: 0.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 58.3ms
# Speed: 0.0ms preprocess, 58.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 54.1ms
# Speed: 2.0ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 48.8ms
# Speed: 3.0ms preprocess, 48.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 41.1ms
# Speed: 2.0ms preprocess, 41.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 52.5ms
# Speed: 15.9ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 58.3ms
# Speed: 0.0ms preprocess, 58.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 59.7ms
# Speed: 0.0ms preprocess, 59.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 49.5ms
# Speed: 4.0ms preprocess, 49.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 50.5ms
# Speed: 0.0ms preprocess, 50.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 60.2ms
# Speed: 0.0ms preprocess, 60.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 56.3ms
# Speed: 10.0ms preprocess, 56.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 63.8ms
# Speed: 0.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 58.8ms
# Speed: 0.0ms preprocess, 58.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 58.4ms
# Speed: 0.0ms preprocess, 58.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 56.9ms
# Speed: 0.0ms preprocess, 56.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 49.2ms
# Speed: 3.0ms preprocess, 49.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 54.5ms
# Speed: 15.0ms preprocess, 54.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 49.9ms
# Speed: 15.0ms preprocess, 49.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 56.0ms
# Speed: 15.6ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 55.6ms
# Speed: 1.0ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 53.3ms
# Speed: 3.0ms preprocess, 53.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 65.9ms
# Speed: 0.0ms preprocess, 65.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 53.9ms
# Speed: 0.0ms preprocess, 53.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 63.1ms
# Speed: 0.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 65.7ms
# Speed: 0.0ms preprocess, 65.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 63.1ms
# Speed: 0.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 51.0ms
# Speed: 0.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 66.8ms
# Speed: 0.0ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 50.3ms
# Speed: 3.2ms preprocess, 50.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 56.3ms
# Speed: 0.0ms preprocess, 56.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 57.7ms
# Speed: 0.0ms preprocess, 57.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.8ms
# Speed: 0.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 55.8ms
# Speed: 3.0ms preprocess, 55.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 55.2ms
# Speed: 2.7ms preprocess, 55.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 55.9ms
# Speed: 0.0ms preprocess, 55.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 63.2ms
# Speed: 0.0ms preprocess, 63.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 63.3ms
# Speed: 0.0ms preprocess, 63.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 59.8ms
# Speed: 0.0ms preprocess, 59.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 49.2ms
# Speed: 2.0ms preprocess, 49.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 53.0ms
# Speed: 15.8ms preprocess, 53.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 50.3ms
# Speed: 17.2ms preprocess, 50.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 56.3ms
# Speed: 0.0ms preprocess, 56.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 57.6ms
# Speed: 2.7ms preprocess, 57.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 53.3ms
# Speed: 1.4ms preprocess, 53.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 57.1ms
# Speed: 15.6ms preprocess, 57.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 56.3ms
# Speed: 11.7ms preprocess, 56.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 96.9ms
# Speed: 3.0ms preprocess, 96.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.2ms
# Speed: 0.0ms preprocess, 62.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 54.1ms
# Speed: 2.0ms preprocess, 54.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 51.7ms
# Speed: 0.0ms preprocess, 51.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 60.8ms
# Speed: 0.0ms preprocess, 60.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 67.2ms
# Speed: 0.0ms preprocess, 67.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 51.5ms
# Speed: 1.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 53.1ms
# Speed: 0.0ms preprocess, 53.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 57.9ms
# Speed: 0.6ms preprocess, 57.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.7ms
# Speed: 0.0ms preprocess, 62.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.0ms
# Speed: 0.0ms preprocess, 62.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.7ms
# Speed: 0.0ms preprocess, 62.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 58.9ms
# Speed: 0.0ms preprocess, 58.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 52.5ms
# Speed: 15.7ms preprocess, 52.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 57.0ms
# Speed: 0.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 52.7ms
# Speed: 0.0ms preprocess, 52.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 64.0ms
# Speed: 0.0ms preprocess, 64.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 53.2ms
# Speed: 0.6ms preprocess, 53.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 71.7ms
# Speed: 0.0ms preprocess, 71.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 55.5ms
# Speed: 0.0ms preprocess, 55.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.6ms
# Speed: 0.0ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 69.3ms
# Speed: 0.0ms preprocess, 69.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 55.1ms
# Speed: 15.5ms preprocess, 55.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 64.9ms
# Speed: 0.0ms preprocess, 64.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 58.9ms
# Speed: 0.0ms preprocess, 58.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 53.1ms
# Speed: 3.0ms preprocess, 53.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 55.1ms
# Speed: 0.0ms preprocess, 55.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 58.4ms
# Speed: 0.0ms preprocess, 58.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 52.1ms
# Speed: 4.0ms preprocess, 52.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 50.8ms
# Speed: 5.5ms preprocess, 50.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 48.6ms
# Speed: 3.3ms preprocess, 48.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 58.8ms
# Speed: 0.0ms preprocess, 58.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 58.5ms
# Speed: 1.7ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.0ms
# Speed: 0.0ms preprocess, 62.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 56.3ms
# Speed: 3.7ms preprocess, 56.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 60.4ms
# Speed: 15.0ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 67.5ms
# Speed: 1.5ms preprocess, 67.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 68.7ms
# Speed: 2.6ms preprocess, 68.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 69.9ms
# Speed: 0.0ms preprocess, 69.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 59.4ms
# Speed: 15.3ms preprocess, 59.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 123.1ms
# Speed: 2.6ms preprocess, 123.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 55.6ms
# Speed: 0.0ms preprocess, 55.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 64.7ms
# Speed: 0.0ms preprocess, 64.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 49.6ms
# Speed: 3.0ms preprocess, 49.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 59.4ms
# Speed: 0.0ms preprocess, 59.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 55.9ms
# Speed: 15.0ms preprocess, 55.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 55.8ms
# Speed: 0.0ms preprocess, 55.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 60.6ms
# Speed: 15.0ms preprocess, 60.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 57.7ms
# Speed: 0.0ms preprocess, 57.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.7ms
# Speed: 3.2ms preprocess, 62.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 80.0ms
# Speed: 13.4ms preprocess, 80.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.0ms
# Speed: 0.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 61.7ms
# Speed: 0.0ms preprocess, 61.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 51.5ms
# Speed: 3.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 63.4ms
# Speed: 0.0ms preprocess, 63.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 57.3ms
# Speed: 0.0ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 56.7ms
# Speed: 3.0ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.8ms
# Speed: 0.0ms preprocess, 62.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 66.0ms
# Speed: 0.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 52.8ms
# Speed: 0.0ms preprocess, 52.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 50.2ms
# Speed: 2.0ms preprocess, 50.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 61.8ms
# Speed: 0.0ms preprocess, 61.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 52.4ms
# Speed: 2.0ms preprocess, 52.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 59.5ms
# Speed: 0.0ms preprocess, 59.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 65.9ms
# Speed: 0.0ms preprocess, 65.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 59.2ms
# Speed: 0.0ms preprocess, 59.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 67.3ms
# Speed: 0.0ms preprocess, 67.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 56.0ms
# Speed: 15.6ms preprocess, 56.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 69.8ms
# Speed: 0.0ms preprocess, 69.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 57.9ms
# Speed: 1.1ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 55.0ms
# Speed: 15.8ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 61.7ms
# Speed: 0.0ms preprocess, 61.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 59.5ms
# Speed: 15.5ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 61.6ms
# Speed: 0.0ms preprocess, 61.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 70.9ms
# Speed: 0.0ms preprocess, 70.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 57.4ms
# Speed: 0.0ms preprocess, 57.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 73.2ms
# Speed: 0.0ms preprocess, 73.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 58.1ms
# Speed: 0.0ms preprocess, 58.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.4ms
# Speed: 6.4ms preprocess, 62.4ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 53.5ms
# Speed: 3.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 67.3ms
# Speed: 0.0ms preprocess, 67.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 54.4ms
# Speed: 3.0ms preprocess, 54.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 55.7ms
# Speed: 0.0ms preprocess, 55.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 60.9ms
# Speed: 0.0ms preprocess, 60.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.6ms
# Speed: 0.0ms preprocess, 62.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 50.1ms
# Speed: 15.0ms preprocess, 50.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 57.3ms
# Speed: 0.0ms preprocess, 57.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 56.2ms
# Speed: 3.2ms preprocess, 56.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 64.6ms
# Speed: 0.0ms preprocess, 64.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 46.4ms
# Speed: 15.6ms preprocess, 46.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 62.8ms
# Speed: 0.0ms preprocess, 62.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 42.9ms
# Speed: 0.0ms preprocess, 42.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 57.4ms
# Speed: 0.0ms preprocess, 57.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 52.8ms
# Speed: 2.6ms preprocess, 52.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 61.3ms
# Speed: 3.0ms preprocess, 61.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 61.7ms
# Speed: 0.0ms preprocess, 61.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 56.4ms
# Speed: 16.0ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 47.6ms
# Speed: 15.0ms preprocess, 47.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 63.3ms
# Speed: 0.0ms preprocess, 63.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 58.1ms
# Speed: 0.0ms preprocess, 58.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 56.0ms
# Speed: 0.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 74.4ms
# Speed: 0.0ms preprocess, 74.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 61.6ms
# Speed: 2.0ms preprocess, 61.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 54.6ms
# Speed: 0.0ms preprocess, 54.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 1 person, 43.5ms
# Speed: 1.9ms preprocess, 43.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 (no detections), 68.8ms
# Speed: 0.0ms preprocess, 68.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 369: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 58.2ms
# Speed: 0.0ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 370: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 52.6ms
# Speed: 1.3ms preprocess, 52.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 371: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 58.5ms
# Speed: 0.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 372: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 60.5ms
# Speed: 0.5ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 373: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 56.9ms
# Speed: 2.0ms preprocess, 56.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 374: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 57.3ms
# Speed: 15.0ms preprocess, 57.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 375: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 52.5ms
# Speed: 2.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 376: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 55.4ms
# Speed: 0.0ms preprocess, 55.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 377: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 62.2ms
# Speed: 0.0ms preprocess, 62.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 378: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 59.6ms
# Speed: 0.0ms preprocess, 59.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
# Error processing frame 379: 'NoneType' object has no attribute 'cpu'
# Tracking results saved to src/playground\tracking_results.csv

# %%
import os
os.chdir("c:\\Users\\bohbot-lab\\git\\Mosquito_Supermodel")

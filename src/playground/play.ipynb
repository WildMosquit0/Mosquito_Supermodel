# %%
import os
import cv2
import pandas as pd
import torch
import json
from ultralytics import YOLO
from datetime import datetime


class Tracker:
    def __init__(self, config_path: str):
        """
        Initialize the Tracker with a configuration file.
        Args:
            config_path (str): Path to the JSON configuration file.
        """
        # Load configuration
        with open(config_path, "r") as config_file:
            self.config = json.load(config_file)

        # Extract settings from the configuration
        self.model_path = self.config["model"]["weights"]
        self.conf_threshold = self.config["model"]["conf_threshold"]
        self.iou_threshold = self.config["model"]["iou_threshold"]

        self.input_dir = self.config["input"]["images_dir"]
        self.output_dir = self.config["output"]["output_dir"]
        self.save_video = self.config["output"]["save_video"]


        # Ensure output directory exists
        os.makedirs(self.output_dir, exist_ok=True)

        # Initialize YOLO model
        if not os.path.exists(self.model_path):
            raise FileNotFoundError(f"Model file {self.model_path} does not exist.")
        self.model = YOLO(self.model_path)
        self.model.to("cuda" if torch.cuda.is_available() else "cpu")

        # Prepare for tracking
        self.global_track_id = 0
        self.track_memory = {}  # Tracks global IDs for cross-image tracking
        self.tracking_data = []  # Store results for all files

    def _process_video(self, video_path: str):
        """
        Process a video file for object tracking.
        Args:
            video_path (str): Path to the video file.
        """
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            print(f"Error: Unable to open video file {video_path}")
            return

        video_name = os.path.basename(video_path)
        video_output_dir = os.path.join(self.output_dir, "annotated_videos")
        os.makedirs(video_output_dir, exist_ok=True)
        output_video_path = os.path.join(video_output_dir, f"annotated_{video_name}")

        try:
            while cap.isOpened():
                success, frame = cap.read()
                if not success:
                    break

                # Get current frame number
                frame_number = int(cap.get(cv2.CAP_PROP_POS_FRAMES))

                # Run YOLO tracking
                try:
                    results = self.model.track(
                        frame,
                        conf=self.conf_threshold,
                        iou=self.iou_threshold,
                        persist=True,
                        save=self.save_video,
                    )

                    # Save annotated frame to video if `save_video` is True
                    if self.save_video:
                        annotated_frame = results[0].plot()
                        if "video_writer" not in locals():
                            # Initialize video writer if not already done
                            fourcc = cv2.VideoWriter_fourcc(*"mp4v")
                            frame_height, frame_width = annotated_frame.shape[:2]
                            video_writer = cv2.VideoWriter(
                                output_video_path, fourcc, cap.get(cv2.CAP_PROP_FPS), (frame_width, frame_height)
                            )
                        video_writer.write(annotated_frame)

                    # Check if there are detections
                    if results and results[0].boxes is not None:
                        boxes = results[0].boxes.xywh.cpu().numpy()  # Bounding boxes
                        track_ids = results[0].boxes.id.cpu().numpy().tolist()  # Track IDs

                        # Append tracking data
                        for box, track_id in zip(boxes, track_ids):
                            x, y, w, h = box
                            self.tracking_data.append([track_id, x, y, w, h, os.path.basename(video_path), frame_number])
                    else:
                        print(f"No detections in frame {frame_number}.")

                except Exception as e:
                    print(f"Error processing frame {frame_number}: {e}")

        except Exception as e:
            print(f"Error processing video {video_path}: {e}")
        finally:
            cap.release()
            # Release video writer
            if "video_writer" in locals():
                video_writer.release()

    def _process_image(self, image_path: str):
        """
        Process a single image for object tracking.
        Args:
            image_path (str): Path to the image file.
        """
        frame = cv2.imread(image_path)
        if frame is None:
            print(f"Error: Unable to open image file {image_path}")
            return

        results = self.model.track(frame, conf=self.conf_threshold, iou=self.iou_threshold, persist=True)

        if results and results[0].boxes is not None:
            boxes = results[0].boxes.xywh.cpu().numpy()
            track_ids = results[0].boxes.id.cpu().numpy().tolist()

            for box, track_id in zip(boxes, track_ids):
                if track_id not in self.track_memory:
                    self.global_track_id += 1
                    self.track_memory[track_id] = self.global_track_id

                global_id = self.track_memory[track_id]
                x, y, w, h = box
                self.tracking_data.append([global_id, x, y, w, h, os.path.basename(image_path), 0])

    def __call__(self):
        """
        Process all images and videos in the input directory or a single file.
        """
        if os.path.isfile(self.input_dir):
            # Process a single file
            input_files = [self.input_dir]
        elif os.path.isdir(self.input_dir):
            # Get all files from the input directory
            input_files = [
                os.path.join(self.input_dir, f)
                for f in os.listdir(self.input_dir)
                if f.lower().endswith((".mp4", ".avi", ".jpg", ".jpeg", ".png"))
            ]
        else:
            raise NotADirectoryError(f"The input path {self.input_dir} is neither a file nor a directory.")

        for input_file in sorted(input_files):
            if input_file.lower().endswith((".mp4", ".avi")):
                print(f"Processing video: {input_file}")
                self._process_video(input_file)
            elif input_file.lower().endswith((".jpg", ".jpeg", ".png")):
                print(f"Processing image: {input_file}")
                self._process_image(input_file)

        # Save results to a CSV file
        output_csv = os.path.join(self.output_dir, "tracking_results.csv")
        df = pd.DataFrame(self.tracking_data, columns=["track_id", "x", "y", "w", "h", "file_name", "frame_number"])
        df.to_csv(output_csv, index=False)
        print(f"Tracking results saved to {output_csv}")

# Usage
if __name__ == "__main__":
    tracker = Tracker(config_path="config.json")
    tracker()  # Call the instance to process files
# Out:
# Processing video: src/tests/13413819-hd_1920_1080_30fps.mp4
#
# 0: 384x640 (no detections), 68.4ms
# Speed: 4.1ms preprocess, 68.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 1: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 2: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 67.0ms
# Speed: 1.0ms preprocess, 67.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 3: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 65.0ms
# Speed: 3.0ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 4: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 63.1ms
# Speed: 4.0ms preprocess, 63.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 5: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 75.5ms
# Speed: 3.0ms preprocess, 75.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 6: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 116.1ms
# Speed: 23.1ms preprocess, 116.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 7: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 64.7ms
# Speed: 2.6ms preprocess, 64.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 8: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 9: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 10: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 11: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 63.0ms
# Speed: 1.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 12: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 56.0ms
# Speed: 4.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 13: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 14: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 15: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 16: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 74.0ms
# Speed: 2.0ms preprocess, 74.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 17: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 60.0ms
# Speed: 4.0ms preprocess, 60.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 18: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 63.2ms
# Speed: 2.0ms preprocess, 63.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 19: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 1 person, 60.0ms
# Speed: 4.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 67.0ms
# Speed: 3.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 54.0ms
# Speed: 3.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 58.1ms
# Speed: 3.0ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 63.5ms
# Speed: 4.0ms preprocess, 63.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 64.0ms
# Speed: 3.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 73.0ms
# Speed: 3.0ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 67.0ms
# Speed: 3.0ms preprocess, 67.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 77.1ms
# Speed: 1.0ms preprocess, 77.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 85.5ms
# Speed: 2.5ms preprocess, 85.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 64.5ms
# Speed: 2.0ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 55.1ms
# Speed: 2.0ms preprocess, 55.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 53.5ms
# Speed: 3.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 57.0ms
# Speed: 1.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 102.0ms
# Speed: 2.0ms preprocess, 102.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 71.5ms
# Speed: 3.0ms preprocess, 71.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 74.5ms
# Speed: 2.0ms preprocess, 74.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 50.4ms
# Speed: 3.0ms preprocess, 50.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 55.0ms
# Speed: 3.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.0ms
# Speed: 5.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 49.0ms
# Speed: 3.0ms preprocess, 49.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 64.5ms
# Speed: 2.0ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 52.4ms
# Speed: 2.0ms preprocess, 52.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 64.0ms
# Speed: 3.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 54.1ms
# Speed: 3.0ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 91.0ms
# Speed: 3.0ms preprocess, 91.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 50.5ms
# Speed: 2.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 65.5ms
# Speed: 3.0ms preprocess, 65.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 96.5ms
# Speed: 3.0ms preprocess, 96.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 59.0ms
# Speed: 4.0ms preprocess, 59.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 68.1ms
# Speed: 3.0ms preprocess, 68.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 50.0ms
# Speed: 3.0ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 51.0ms
# Speed: 4.0ms preprocess, 51.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 68.0ms
# Speed: 1.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 168.9ms
# Speed: 2.0ms preprocess, 168.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 91.1ms
# Speed: 2.1ms preprocess, 91.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 70.5ms
# Speed: 4.0ms preprocess, 70.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 151.2ms
# Speed: 2.1ms preprocess, 151.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 70.9ms
# Speed: 4.5ms preprocess, 70.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 59.0ms
# Speed: 1.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 64.0ms
# Speed: 5.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 88.1ms
# Speed: 3.0ms preprocess, 88.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 113.5ms
# Speed: 3.0ms preprocess, 113.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 65.5ms
# Speed: 5.0ms preprocess, 65.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 60.2ms
# Speed: 2.0ms preprocess, 60.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 92.5ms
# Speed: 4.0ms preprocess, 92.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 66.5ms
# Speed: 2.0ms preprocess, 66.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 67.5ms
# Speed: 2.0ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 65.5ms
# Speed: 2.0ms preprocess, 65.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 63.0ms
# Speed: 3.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 62.5ms
# Speed: 2.0ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 59.1ms
# Speed: 2.0ms preprocess, 59.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 62.5ms
# Speed: 3.0ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 62.6ms
# Speed: 2.0ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 55.1ms
# Speed: 2.0ms preprocess, 55.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 65.0ms
# Speed: 3.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 55.5ms
# Speed: 1.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 65.6ms
# Speed: 2.0ms preprocess, 65.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 57.6ms
# Speed: 2.0ms preprocess, 57.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 51.5ms
# Speed: 2.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 55.0ms
# Speed: 3.0ms preprocess, 55.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.5ms
# Speed: 1.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 53.5ms
# Speed: 3.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 57.6ms
# Speed: 2.0ms preprocess, 57.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 60.1ms
# Speed: 1.0ms preprocess, 60.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 54.1ms
# Speed: 2.0ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 66.5ms
# Speed: 2.0ms preprocess, 66.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 84.5ms
# Speed: 2.0ms preprocess, 84.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 63.5ms
# Speed: 4.0ms preprocess, 63.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 81.0ms
# Speed: 2.0ms preprocess, 81.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 59.0ms
# Speed: 4.0ms preprocess, 59.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 98.5ms
# Speed: 3.0ms preprocess, 98.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 70.0ms
# Speed: 4.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 74.0ms
# Speed: 4.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 80.1ms
# Speed: 2.0ms preprocess, 80.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 77.0ms
# Speed: 5.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 58.5ms
# Speed: 1.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 73.0ms
# Speed: 2.5ms preprocess, 73.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 85.0ms
# Speed: 3.0ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 77.0ms
# Speed: 3.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 53.0ms
# Speed: 3.0ms preprocess, 53.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 51.3ms
# Speed: 3.0ms preprocess, 51.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 82.5ms
# Speed: 3.0ms preprocess, 82.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 80.6ms
# Speed: 2.0ms preprocess, 80.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 73.5ms
# Speed: 4.0ms preprocess, 73.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 148.1ms
# Speed: 2.0ms preprocess, 148.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 77.0ms
# Speed: 5.5ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 75.0ms
# Speed: 2.0ms preprocess, 75.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 62.6ms
# Speed: 3.0ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 66.2ms
# Speed: 2.0ms preprocess, 66.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 64.5ms
# Speed: 3.0ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 88.5ms
# Speed: 5.0ms preprocess, 88.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 86.6ms
# Speed: 3.0ms preprocess, 86.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 85.5ms
# Speed: 3.0ms preprocess, 85.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 86.0ms
# Speed: 3.0ms preprocess, 86.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 96.0ms
# Speed: 2.0ms preprocess, 96.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 80.0ms
# Speed: 2.0ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 79.6ms
# Speed: 2.0ms preprocess, 79.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 76.5ms
# Speed: 5.0ms preprocess, 76.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 86.3ms
# Speed: 3.0ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 84.0ms
# Speed: 2.0ms preprocess, 84.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.6ms
# Speed: 2.0ms preprocess, 56.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 70.6ms
# Speed: 3.0ms preprocess, 70.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 71.0ms
# Speed: 6.6ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 118.1ms
# Speed: 3.0ms preprocess, 118.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 83.5ms
# Speed: 5.0ms preprocess, 83.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 77.0ms
# Speed: 3.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 61.6ms
# Speed: 2.0ms preprocess, 61.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 55.5ms
# Speed: 3.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 112.5ms
# Speed: 3.0ms preprocess, 112.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 53.0ms
# Speed: 3.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 51.0ms
# Speed: 2.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 51.0ms
# Speed: 3.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 51.0ms
# Speed: 2.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 63.5ms
# Speed: 3.0ms preprocess, 63.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 67.5ms
# Speed: 4.0ms preprocess, 67.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 76.0ms
# Speed: 3.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 67.0ms
# Speed: 3.0ms preprocess, 67.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 68.0ms
# Speed: 3.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 81.6ms
# Speed: 3.0ms preprocess, 81.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 80.5ms
# Speed: 2.0ms preprocess, 80.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 74.0ms
# Speed: 3.0ms preprocess, 74.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 71.1ms
# Speed: 5.0ms preprocess, 71.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 113.1ms
# Speed: 2.0ms preprocess, 113.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 57.6ms
# Speed: 2.0ms preprocess, 57.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 52.2ms
# Speed: 2.0ms preprocess, 52.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 73.0ms
# Speed: 3.0ms preprocess, 73.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 70.0ms
# Speed: 3.0ms preprocess, 70.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 71.0ms
# Speed: 2.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 89.6ms
# Speed: 3.0ms preprocess, 89.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 78.6ms
# Speed: 2.0ms preprocess, 78.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 78.5ms
# Speed: 2.0ms preprocess, 78.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 73.0ms
# Speed: 5.0ms preprocess, 73.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 74.0ms
# Speed: 2.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 75.2ms
# Speed: 2.0ms preprocess, 75.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 62.0ms
# Speed: 4.0ms preprocess, 62.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 67.0ms
# Speed: 3.0ms preprocess, 67.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 58.6ms
# Speed: 2.0ms preprocess, 58.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 57.5ms
# Speed: 2.5ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 107.6ms
# Speed: 3.0ms preprocess, 107.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 156.8ms
# Speed: 2.6ms preprocess, 156.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 71.9ms
# Speed: 2.6ms preprocess, 71.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 135.8ms
# Speed: 22.5ms preprocess, 135.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 53.0ms
# Speed: 1.0ms preprocess, 53.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 54.0ms
# Speed: 3.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 50.5ms
# Speed: 2.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 64.0ms
# Speed: 5.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 58.0ms
# Speed: 2.5ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 71.0ms
# Speed: 3.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 77.5ms
# Speed: 4.0ms preprocess, 77.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 76.5ms
# Speed: 3.0ms preprocess, 76.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 143.0ms
# Speed: 2.0ms preprocess, 143.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 76.0ms
# Speed: 2.0ms preprocess, 76.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 76.6ms
# Speed: 2.0ms preprocess, 76.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 86.5ms
# Speed: 2.0ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 88.0ms
# Speed: 2.0ms preprocess, 88.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 89.0ms
# Speed: 2.0ms preprocess, 89.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 62.5ms
# Speed: 2.0ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 63.6ms
# Speed: 2.0ms preprocess, 63.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 59.6ms
# Speed: 3.0ms preprocess, 59.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 74.5ms
# Speed: 2.0ms preprocess, 74.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 75.0ms
# Speed: 3.0ms preprocess, 75.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 85.5ms
# Speed: 3.0ms preprocess, 85.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 79.5ms
# Speed: 3.0ms preprocess, 79.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 67.6ms
# Speed: 2.0ms preprocess, 67.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 73.0ms
# Speed: 1.0ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 76.0ms
# Speed: 1.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 79.6ms
# Speed: 3.0ms preprocess, 79.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 66.0ms
# Speed: 3.5ms preprocess, 66.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 74.5ms
# Speed: 2.0ms preprocess, 74.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 80.0ms
# Speed: 2.0ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 64.0ms
# Speed: 3.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 72.5ms
# Speed: 5.0ms preprocess, 72.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 73.5ms
# Speed: 3.0ms preprocess, 73.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 75.0ms
# Speed: 3.0ms preprocess, 75.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 76.0ms
# Speed: 6.0ms preprocess, 76.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 84.5ms
# Speed: 4.0ms preprocess, 84.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 80.5ms
# Speed: 3.0ms preprocess, 80.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 74.5ms
# Speed: 5.0ms preprocess, 74.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 78.1ms
# Speed: 3.0ms preprocess, 78.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 64.0ms
# Speed: 3.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 74.6ms
# Speed: 2.0ms preprocess, 74.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 77.5ms
# Speed: 3.0ms preprocess, 77.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 74.0ms
# Speed: 5.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 64.5ms
# Speed: 2.0ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 1 person, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
#
# 0: 384x640 (no detections), 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 369: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 114.4ms
# Speed: 3.0ms preprocess, 114.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 370: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 371: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 67.5ms
# Speed: 2.0ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 372: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 63.5ms
# Speed: 3.0ms preprocess, 63.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 373: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 374: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 375: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 56.0ms
# Speed: 4.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 376: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 377: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 378: 'NoneType' object has no attribute 'cpu'
#
# 0: 384x640 (no detections), 66.5ms
# Speed: 2.0ms preprocess, 66.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track3
# Error processing frame 379: 'NoneType' object has no attribute 'cpu'
# Tracking results saved to src/playground\tracking_results.csv

# %%
img = "ergerg.png"
img.split(".")[0]
# Out:
# 'ergerg'

# %%
import os
os.chdir("c:\\Users\\bohbot-lab\\git\\Mosquito_Supermodel")

# %%
import cv2

# Define the input and output file paths
input_video_path = r'src/tests/vids/test1/vecteezy_four-people-group-of-happy-teenagers-raising-hands-jumping_6619202.mov'
output_video_path = r'src/tests/vids/test1/reduced_quality_video.mov'

# Open the video file
cap = cv2.VideoCapture(input_video_path)
if not cap.isOpened():
    raise ValueError("Error opening video file. Please check the file path.")

# Get video properties
fps = int(cap.get(cv2.CAP_PROP_FPS))
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for the output video

# Define the output video writer with reduced resolution (640x480)
out = cv2.VideoWriter(output_video_path, fourcc, fps, (640, 480))

# Process each frame
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    # Resize the frame to 640x480
    resized_frame = cv2.resize(frame, (640, 480))
    
    # Write the resized frame to the output video
    out.write(resized_frame)

# Release resources
cap.release()
out.release()

output_video_path  # Return the path to the reduced quality video file
# Out:
# 'src/tests/vids/test1/reduced_quality_video.mov'

# %%
from ultralytics import YOLO
model = YOLO("yolo11n.pt")  # pretrained YOLO11n model

# Run batched inference on a list of images
results = model("0.jpg")  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
    result.show()  # display to screen
    result.save(filename="result.jpg")  # save to disk
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
#
# Traceback (most recent call last):
#   File "/home/wildmosquit0/.vscode/extensions/ms-python.python-2024.22.1-linux-x64/python_files/python_server.py", line 133, in exec_user_input
#     retval = callable_(user_input, user_globals)
#   File "<string>", line 5, in <module>
#   File "/home/wildmosquit0/miniconda3/envs/sp/lib/python3.9/site-packages/ultralytics/engine/model.py", line 180, in __call__
#     return self.predict(source, stream, **kwargs)
#   File "/home/wildmosquit0/miniconda3/envs/sp/lib/python3.9/site-packages/ultralytics/engine/model.py", line 558, in predict
#     return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#   File "/home/wildmosquit0/miniconda3/envs/sp/lib/python3.9/site-packages/ultralytics/engine/predictor.py", line 173, in __call__
#     return list(self.stream_inference(source, model, *args, **kwargs))  # merge list of Result into one
#   File "/home/wildmosquit0/miniconda3/envs/sp/lib/python3.9/site-packages/torch/utils/_contextlib.py", line 36, in generator_context
#     response = gen.send(None)
#   File "/home/wildmosquit0/miniconda3/envs/sp/lib/python3.9/site-packages/ultralytics/engine/predictor.py", line 231, in stream_inference
#     self.setup_source(source if source is not None else self.args.source)
#   File "/home/wildmosquit0/miniconda3/envs/sp/lib/python3.9/site-packages/ultralytics/engine/predictor.py", line 203, in setup_source
#     self.dataset = load_inference_source(
#   File "/home/wildmosquit0/miniconda3/envs/sp/lib/python3.9/site-packages/ultralytics/data/build.py", line 187, in load_inference_source
#     source, stream, screenshot, from_img, in_memory, tensor = check_source(source)
#   File "/home/wildmosquit0/miniconda3/envs/sp/lib/python3.9/site-packages/ultralytics/data/build.py", line 162, in check_source
#     source = autocast_list(source)  # convert all list elements to PIL or np arrays
#   File "/home/wildmosquit0/miniconda3/envs/sp/lib/python3.9/site-packages/ultralytics/data/loaders.py", line 592, in autocast_list
#     files.append(Image.open(requests.get(im, stream=True).raw if str(im).startswith("http") else im))
#   File "/home/wildmosquit0/miniconda3/envs/sp/lib/python3.9/site-packages/PIL/Image.py", line 3469, in open
#     fp = builtins.open(filename, "rb")
# FileNotFoundError: [Errno 2] No such file or directory: '/home/wildmosquit0/git/Mosquito_Supermodel/image1.jpg'
